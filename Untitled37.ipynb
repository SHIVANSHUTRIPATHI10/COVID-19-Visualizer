# %% [markdown]
# <a href="https://colab.research.google.com/github/SHIVANSHUTRIPATHI10/COVID-19-Visualizer/blob/main/Untitled37.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
#directory of file in read mode
file_directory = r"/content/loan_approval_dataset.csv"
#reading the file
with open(file_directory,"r") as loan_data:
    df = pd.read_csv(file_directory)
    print(df)
# Out:
#       loan_id   no_of_dependents      education  self_employed   income_annum  \
# 0           1                  2       Graduate             No        9600000
# 1           2                  0   Not Graduate            Yes        4100000
# 2           3                  3       Graduate             No        9100000
# 3           4                  3       Graduate             No        8200000
# 4           5                  5   Not Graduate            Yes        9800000
# ...       ...                ...            ...            ...            ...
# 4264     4265                  5       Graduate            Yes        1000000
# 4265     4266                  0   Not Graduate            Yes        3300000
# 4266     4267                  2   Not Graduate             No        6500000
# 4267     4268                  1   Not Graduate             No        4100000
# 4268     4269                  1       Graduate             No        9200000
#
#        loan_amount   loan_term   cibil_score   residential_assets_value  \
# 0         29900000          12           778                    2400000
# 1         12200000           8           417                    2700000
# 2         29700000          20           506                    7100000
# 3         30700000           8           467                   18200000
# 4         24200000          20           382                   12400000
# ...            ...         ...           ...                        ...
# 4264       2300000          12           317                    2800000
# 4265      11300000          20           559                    4200000
# 4266      23900000          18           457                    1200000
# 4267      12800000           8           780                    8200000
# 4268      29700000          10           607                   17800000
#
#        commercial_assets_value   luxury_assets_value   bank_asset_value  \
# 0                     17600000              22700000            8000000
# 1                      2200000               8800000            3300000
# 2                      4500000              33300000           12800000
# 3                      3300000              23300000            7900000
# 4                      8200000              29400000            5000000
# ...                        ...                   ...                ...
# 4264                    500000               3300000             800000
# 4265                   2900000              11000000            1900000
# 4266                  12400000              18100000            7300000
# 4267                    700000              14100000            5800000
# 4268                  11800000              35700000           12000000
#
#       loan_status
# 0        Approved
# 1        Rejected
# 2        Rejected
# 3        Rejected
# 4        Rejected
# ...           ...
# 4264     Rejected
# 4265     Approved
# 4266     Rejected
# 4267     Approved
# 4268     Approved
#
# [4269 rows x 13 columns]

# %%
df.describe()
# Out:
#            loan_id   no_of_dependents   income_annum   loan_amount  \
# count  4269.000000        4269.000000   4.269000e+03  4.269000e+03
# mean   2135.000000           2.498712   5.059124e+06  1.513345e+07
# std    1232.498479           1.695910   2.806840e+06  9.043363e+06
# min       1.000000           0.000000   2.000000e+05  3.000000e+05
# 25%    1068.000000           1.000000   2.700000e+06  7.700000e+06
# 50%    2135.000000           3.000000   5.100000e+06  1.450000e+07
# 75%    3202.000000           4.000000   7.500000e+06  2.150000e+07
# max    4269.000000           5.000000   9.900000e+06  3.950000e+07
#
#          loan_term   cibil_score   residential_assets_value  \
# count  4269.000000   4269.000000               4.269000e+03
# mean     10.900445    599.936051               7.472617e+06
# std       5.709187    172.430401               6.503637e+06
# min       2.000000    300.000000              -1.000000e+05
# 25%       6.000000    453.000000               2.200000e+06
# 50%      10.000000    600.000000               5.600000e+06
# 75%      16.000000    748.000000               1.130000e+07
# max      20.000000    900.000000               2.910000e+07
#
#         commercial_assets_value   luxury_assets_value   bank_asset_value
# count              4.269000e+03          4.269000e+03       4.269000e+03
# mean               4.973155e+06          1.512631e+07       4.976692e+06
# std                4.388966e+06          9.103754e+06       3.250185e+06
# min                0.000000e+00          3.000000e+05       0.000000e+00
# 25%                1.300000e+06          7.500000e+06       2.300000e+06
# 50%                3.700000e+06          1.460000e+07       4.600000e+06
# 75%                7.600000e+06          2.170000e+07       7.100000e+06
# max                1.940000e+07          3.920000e+07       1.470000e+07

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4269 entries, 0 to 4268
# Data columns (total 13 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   loan_id                    4269 non-null   int64
#  1    no_of_dependents          4269 non-null   int64
#  2    education                 4269 non-null   object
#  3    self_employed             4269 non-null   object
#  4    income_annum              4269 non-null   int64
#  5    loan_amount               4269 non-null   int64
#  6    loan_term                 4269 non-null   int64
#  7    cibil_score               4269 non-null   int64
#  8    residential_assets_value  4269 non-null   int64
#  9    commercial_assets_value   4269 non-null   int64
#  10   luxury_assets_value       4269 non-null   int64
#  11   bank_asset_value          4269 non-null   int64
#  12   loan_status               4269 non-null   object
# dtypes: int64(10), object(3)
# memory usage: 433.7+ KB

# %%
df.size
# Out:
# 55497

# %%
data_column = df.select_dtypes(include = ['int']).columns.tolist()
data_column
# Out:
# ['loan_id',
#  ' no_of_dependents',
#  ' income_annum',
#  ' loan_amount',
#  ' loan_term',
#  ' cibil_score',
#  ' residential_assets_value',
#  ' commercial_assets_value',
#  ' luxury_assets_value',
#  ' bank_asset_value']

# %%
data_column = df.select_dtypes(include = ['object']).columns.tolist()
data_column
# Out:
# [' education', ' self_employed', ' loan_status']

# %%
df[' bank_asset_value'].unique()
# Out:
# array([ 8000000,  3300000, 12800000,  7900000,  5000000,  5100000,
#         4300000,  6000000,   600000,  1600000,  3100000,  6400000,
#         1900000,  4400000,   700000,  5900000,  6100000,  5400000,
#         8500000,   300000,  2600000,  7200000,  2500000,  9700000,
#         9300000,  1000000,  5800000,   900000,  1400000,  7100000,
#         2900000,  9000000,  5200000,   800000, 10900000,  4900000,
#         6500000,  8200000, 11700000, 10500000, 11300000,  3400000,
#         6200000,  8700000,  4100000,  4800000, 11400000,  4700000,
#         2800000, 11900000,  5500000,  2400000,  4200000,  7600000,
#         5600000,  2000000,  1100000,  6300000, 11100000,  8600000,
#         6800000,  3600000, 10200000, 12700000,  2100000,  1300000,
#          400000,  7000000,  7300000,   100000,   200000, 11600000,
#         1800000,  9800000,  8100000,  7500000, 13400000,  9600000,
#         3800000,  8400000,  3200000,  1200000,  4600000,  8300000,
#         4500000,  3500000,  2300000,  7400000,  1700000,  9500000,
#         3000000,  2200000,  9200000,  4000000, 11200000,   500000,
#         9400000, 14400000, 10000000,  6600000, 12500000,  1500000,
#         9100000,  7700000,  7800000, 10300000,  9900000,  8800000,
#         5700000, 10400000, 11800000,  5300000, 12400000,  2700000,
#        11500000,  3900000,        0, 10800000,  6700000, 12900000,
#        12300000,  6900000, 12200000, 13500000,  8900000,  3700000,
#        12100000, 13600000, 13100000, 10600000, 13900000, 12000000,
#        13000000, 10100000, 10700000, 11000000, 13200000, 14700000,
#        14000000, 13300000, 13800000, 14600000, 14300000, 14200000,
#        13700000, 14100000])

# %%
df.isna().sum()
# Out:
# loan_id                      0
#  no_of_dependents            0
#  education                   0
#  self_employed               0
#  income_annum                0
#  loan_amount                 0
#  loan_term                   0
#  cibil_score                 0
#  residential_assets_value    0
#  commercial_assets_value     0
#  luxury_assets_value         0
#  bank_asset_value            0
#  loan_status                 0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
#creating dummy data
df_dummy = pd.get_dummies(df)

# %%
df_dummy.drop('loan_id',axis = 1 , inplace=True)

# %%
df_dummy
# Out:
#        no_of_dependents   income_annum   loan_amount   loan_term  \
# 0                     2        9600000      29900000          12
# 1                     0        4100000      12200000           8
# 2                     3        9100000      29700000          20
# 3                     3        8200000      30700000           8
# 4                     5        9800000      24200000          20
# ...                 ...            ...           ...         ...
# 4264                  5        1000000       2300000          12
# 4265                  0        3300000      11300000          20
# 4266                  2        6500000      23900000          18
# 4267                  1        4100000      12800000           8
# 4268                  1        9200000      29700000          10
#
#        cibil_score   residential_assets_value   commercial_assets_value  \
# 0              778                    2400000                  17600000
# 1              417                    2700000                   2200000
# 2              506                    7100000                   4500000
# 3              467                   18200000                   3300000
# 4              382                   12400000                   8200000
# ...            ...                        ...                       ...
# 4264           317                    2800000                    500000
# 4265           559                    4200000                   2900000
# 4266           457                    1200000                  12400000
# 4267           780                    8200000                    700000
# 4268           607                   17800000                  11800000
#
#        luxury_assets_value   bank_asset_value  loan_term_log  \
# 0                 22700000            8000000       2.484907
# 1                  8800000            3300000       2.079442
# 2                 33300000           12800000       2.995732
# 3                 23300000            7900000       2.079442
# 4                 29400000            5000000       2.995732
# ...                    ...                ...            ...
# 4264               3300000             800000       2.484907
# 4265              11000000            1900000       2.995732
# 4266              18100000            7300000       2.890372
# 4267              14100000            5800000       2.079442
# 4268              35700000           12000000       2.302585
#
#        education_ Graduate   education_ Not Graduate   self_employed_ No  \
# 0                     True                     False                True
# 1                    False                      True               False
# 2                     True                     False                True
# 3                     True                     False                True
# 4                    False                      True               False
# ...                    ...                       ...                 ...
# 4264                  True                     False               False
# 4265                 False                      True               False
# 4266                 False                      True                True
# 4267                 False                      True                True
# 4268                  True                     False                True
#
#        self_employed_ Yes   loan_status_ Approved   loan_status_ Rejected
# 0                   False                    True                   False
# 1                    True                   False                    True
# 2                   False                   False                    True
# 3                   False                   False                    True
# 4                    True                   False                    True
# ...                   ...                     ...                     ...
# 4264                 True                   False                    True
# 4265                 True                    True                   False
# 4266                False                   False                    True
# 4267                False                    True                   False
# 4268                False                    True                   False
#
# [4269 rows x 16 columns]

# %%
df_dummy.columns
# Out:
# Index([' no_of_dependents', ' income_annum', ' loan_amount', ' loan_term',
#        ' cibil_score', ' residential_assets_value', ' commercial_assets_value',
#        ' luxury_assets_value', ' bank_asset_value', 'loan_term_log',
#        ' education_ Graduate', ' education_ Not Graduate',
#        ' self_employed_ No', ' self_employed_ Yes', ' loan_status_ Approved',
#        ' loan_status_ Rejected'],
#       dtype='object')

# %%
df_dummy = df.columns.str.strip()
df_dummy
#remove all leading and trailing space
# Out:
# Index(['loan_id', 'no_of_dependents', 'education', 'self_employed',
#        'income_annum', 'loan_amount', 'loan_term', 'cibil_score',
#        'residential_assets_value', 'commercial_assets_value',
#        'luxury_assets_value', 'bank_asset_value', 'loan_status'],
#       dtype='object')

# %%
df_dummy
# Out:
# Index(['loan_id', 'no_of_dependents', 'education', 'self_employed',
#        'income_annum', 'loan_amount', 'loan_term', 'cibil_score',
#        'residential_assets_value', 'commercial_assets_value',
#        'luxury_assets_value', 'bank_asset_value', 'loan_status'],
#       dtype='object')

# %%
#df_dummy['loan_term_log'] = np.log(df_dummy['loan_term'])
df_dummy = pd.get_dummies(df)

# %%
df_dummy = df.copy()

# %%
df_dummy.columns = df_dummy.columns.str.strip()
'loan_term' in df_dummy.columns
df_dummy.columns
# Out:
# Index(['loan_id', 'no_of_dependents', 'education', 'self_employed',
#        'income_annum', 'loan_amount', 'loan_term', 'cibil_score',
#        'residential_assets_value', 'commercial_assets_value',
#        'luxury_assets_value', 'bank_asset_value', 'loan_status',
#        'loan_term_log'],
#       dtype='object')

# %%
df['loan_term_log'] = np.log(df_dummy['loan_term'])
sns.displot(df['loan_term_log'],color = 'red',kde=True)


plt.title("loan term")
plt.show()
#

# %%
df_dummy["loan_amount_term"] = np.log(df_dummy["loan_amount"])
sns.displot(df_dummy["loan_amount_term"],kde=True)

# %%
plot = df_dummy.groupby('education')['cibil_score'].max()
plot.plot(kind = 'barh')
plt.show()

# %%
#outliers
col = [" loan_term"," no_of_dependents"," loan_amount"," cibil_score"," income_annum"," bank_asset_value"," residential_assets_value"," commercial_assets_value"," loan_term"]
df_clean = df.copy()
for i in col:
  q1 = df_clean[i].quantile(0.25)
  q3 = df_clean[i].quantile(0.75)
  iqr = q3-q1
  upper_limit = q3 + 1.5*iqr
  lower_limit = q1 - 1.5*iqr
  df_clean = df_clean[(df_clean[i] <= upper_limit) & (df_clean[i] >= lower_limit)]

# %%
df_clean[' loan_term']
# Out:
# 1        8
# 2       20
# 3        8
# 4       20
# 5       10
#         ..
# 4264    12
# 4265    20
# 4266    18
# 4267     8
# 4268    10
# Name:  loan_term, Length: 4178, dtype: int64

# %%
# Out:
# pandas.core.series.Series

# %%
# Out:
# loan_term                         21.0
# no_of_dependents                   5.5
# loan_amount                 28400000.0
# cibil_score                      895.5
# income_annum                 9900000.0
# bank_asset_value             9500000.0
# residential_assets_value    15850000.0
# commercial_assets_value     10750000.0
# loan_term                         21.0
# dtype: float64

# %%
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-3845393346.py in <cell line: 0>()
# ----> 1 lower_limit = float(q1 - 1.5 * iqr)
#       2 upper_limit = float(q3 + 1.5 * iqr)
#       3 #def removing_outliers(lower_limit, upper_limit, df):
#       4  #       (df['loan_term'] >= lower_limit) &
#       5   #      (df['loan_term'] <= upper_limit)
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/series.py in wrapper(self)
#     246             )
#     247             return converter(self.iloc[0])
# --> 248         raise TypeError(f"cannot convert the series to {converter}")
#     249
#     250     wrapper.__name__ = f"__{converter.__name__}__"
#
# TypeError: cannot convert the series to <class 'float'>
